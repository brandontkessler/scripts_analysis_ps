# %%
from data_transformations_ps.dashboards.marketing import single_builder

# %%
single_builder(qtr=1, fy=20, to_date='12/30/2019')
# Out:
# {'%_to_goal': 36.9,
#  'tickets sold': 20215.0,
#  'households': 4124,
#  'new_to_file': 1694,
#  'retained_new_to_file': 109,
#  'three_concerts_current_and_py': 536}

# %%
109 / 1694
# Out:
# 0.06434474616292798
