# %%
from data_transformations_ps import TierAnalysis

# %%
donor_tiers = TierAnalysis()

# %%
donor_tiers.do_tier_analysis()
# Out:
# Success: Updated self.tier_counts and self.tier_revenue

# %%
donor_tiers.plot_tier_revenue()

# %%
donor_tiers.plot_tier_counts()
