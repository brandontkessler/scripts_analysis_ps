# %% [markdown]
# Pull data files for Tickets, Donors (file_yr=13), and Capacity rating for attributes

# %%
from data_transformations_ps.dashboards.development import dev_builder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-beaa591ce631> in <module>
# ----> 1 from data_transformations_ps.dashboards.development import dev_builder
#
# ModuleNotFoundError: No module named 'data_transformations_ps'

# %%
dev_builder(fy=20, file_yr=13)
# Out:
# Success: Updated self.tier_counts and self.tier_revenue
# {'upgrade': '0.15%',
#  'downgrade': '2.81%',
#  'total retention': '6.05%',
#  'high capacity prospects': 421,
#  'avg activities by high cap prospects': 0.9073634204275535}
