# %%
from ab_experiments import StarWars
from data_transformations_ps import Tickets

# %%
t = Tickets(fys=[2020]).drop_na_rows().convert_dates()

# %%
star_wars = StarWars(ticketing_df=t.data, prior_c=1.0)

# %%
posteriors = star_wars.generate_posteriors()

# %%
StarWars.plot_posteriors(posteriors=posteriors, plot_title='Star Wars ABC Experiment')

# %%
print(star_wars)
# Out:
# experiment_a: {'participants': 128, 'customers': 7, 'tickets': 24, 'revenue': 642.5, 'successes': 7, 'failures': 121}
# experiment_b: {'participants': 129, 'customers': 4, 'tickets': 12, 'revenue': 553.0, 'successes': 4, 'failures': 125}
# experiment_c: {'participants': 129, 'customers': 2, 'tickets': 6, 'revenue': 283.0, 'successes': 2, 'failures': 127}
