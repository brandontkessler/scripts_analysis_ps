# %%
from ab_experiments import StarWars
from data_transformations_ps import Tickets

# %%
t = Tickets(fys=[20])

# %%
star_wars = StarWars(ticketing_df=t.data, prior_c=1.0)

# %%
star_wars.generate_posteriors()
# Out:
# Posteriors ready for plots

# %%
star_wars.plot_posteriors(plot_title='Star Wars ABC Experiment')

# %%
print(star_wars)
# Out:
# experiment_a: {'participants': 128, 'customers': 8, 'tickets': 42, 'revenue': 1140.5, 'successes': 8, 'failures': 120}
# experiment_b: {'participants': 129, 'customers': 10, 'tickets': 45, 'revenue': 1802.0, 'successes': 10, 'failures': 119}
# experiment_c: {'participants': 129, 'customers': 2, 'tickets': 6, 'revenue': 283.0, 'successes': 2, 'failures': 127}
